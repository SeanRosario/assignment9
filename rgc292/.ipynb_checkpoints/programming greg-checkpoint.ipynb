# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd

df1 = pd.read_excel('indicator gapminder gdp_per_capita_ppp.xlsx')
df1
# Out:
#                       gdp pc test         1800         1801         1802  \
# 0                        Abkhazia          NaN          NaN          NaN
# 1                     Afghanistan   472.053500   472.053500   472.053500
# 2           Akrotiri and Dhekelia          NaN          NaN          NaN
# 3                         Albania   601.215222   601.839631   602.464688
# 4                         Algeria   766.253664   766.234779   766.215895
# 5                  American Samoa   674.453726   674.453726   674.453726
# 6                         Andorra  1260.123256  1262.214402  1264.309018
# 7                          Angola   359.932582   359.932582   359.932582
# 8                        Anguilla   775.668711   775.668711   775.668711
# 9             Antigua and Barbuda   538.376199   538.376199   538.376199
# 10                      Argentina   871.625269   871.625269   871.625269
# 11                        Armenia   378.403254   378.403254   378.403254
# ...

# %%
w = df[0:][1:2]
w
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-10ad985abbb9> in <module>()
# ----> 1 w = df[0:][1:2]
#       2 w
#
# NameError: name 'df' is not defined

# %%
s = df[0:][0:1]

#s[1:][0:1]
s
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-cd9b10c8abf2> in <module>()
# ----> 1 s = df[0:][0:1]
#       2
#       3 #s[1:][0:1]
#       4 s
#
# NameError: name 'df' is not defined

# %%
dft = df1.transpose()

# %%
dft
# Out:
#                   0            1                      2        3        4    \
# gdp pc test  Abkhazia  Afghanistan  Akrotiri and Dhekelia  Albania  Algeria
# 1800              NaN      472.053                    NaN  601.215  766.254
# 1801              NaN      472.053                    NaN   601.84  766.235
# 1802              NaN      472.053                    NaN  602.465  766.216
# 1803              NaN      472.053                    NaN   603.09  766.197
# 1804              NaN      472.053                    NaN  603.717  766.178
# 1805              NaN      472.053                    NaN  604.344  766.159
# 1806              NaN      472.053                    NaN  604.971   766.14
# 1807              NaN      472.053                    NaN    605.6  766.121
# 1808              NaN      472.053                    NaN  606.229  766.103
# 1809              NaN      472.053                    NaN  606.858  766.084
# ...

# %%
df1.rename(columns={'gdp pc test': 'Country'}, inplace=True)
df1
# Out:
#                           Country         1800         1801         1802  \
# 0                        Abkhazia          NaN          NaN          NaN
# 1                     Afghanistan   472.053500   472.053500   472.053500
# 2           Akrotiri and Dhekelia          NaN          NaN          NaN
# 3                         Albania   601.215222   601.839631   602.464688
# 4                         Algeria   766.253664   766.234779   766.215895
# 5                  American Samoa   674.453726   674.453726   674.453726
# 6                         Andorra  1260.123256  1262.214402  1264.309018
# 7                          Angola   359.932582   359.932582   359.932582
# 8                        Anguilla   775.668711   775.668711   775.668711
# 9             Antigua and Barbuda   538.376199   538.376199   538.376199
# 10                      Argentina   871.625269   871.625269   871.625269
# 11                        Armenia   378.403254   378.403254   378.403254
# ...

# %%
import numpy as np
import pylab as pl
df1 = pd.DataFrame(df1[:][1800])
df1.to_csv('data.csv', sep=',')
pl.figure()
pl.subplot(511)

#ax = fig.add_subplot(3,1,1)
df1.loc[:53][1800].plot(kind='bar')
pl.xticks(range(0,53), df1.loc[:53]['Country'])
pl.title('Subplot')
pl.xlabel('X')
pl.ylabel('Y')
#ax.set_xlabel
#fig.set_size_inches(200, 30, forward=True)

"""#ax2 = fig.add_subplot(3,1,2)
pl.subplot(512)
df1.iloc[53:105][1800].plot(kind='bar')
pl.xticks(range(53,105), df1.iloc[53:105]['Country'].values)
pl.title('Subplot')
pl.xlabel('X')
pl.ylabel('Y')
#ax2.set_xticklabels(df1.iloc[130:]['Country'], rotation=85, fontsize='small')
#ax2.set_xlabel

pl.subplot(513)
df1.iloc[105:157][1800].plot(kind='bar')
#pl.xticks(range(105,157), df1.iloc[105:157]['Country'], rotation=80)
pl.title('Subplot')
pl.xlabel('X')
pl.ylabel('Y')

pl.subplot(514)
df1.iloc[157:209][1800].plot(kind='bar')
#pl.xticks(range(157,209), df1.iloc[157:209]['Country'], rotation=80)
pl.title('Subplot')
pl.xlabel('X')
pl.ylabel('Y')

pl.subplot(515)
df1.iloc[209:][1800].plot(kind='bar')
#pl.xticks(range(209,260), df1.iloc[209:]['Country'], rotation=80)
pl.title('Subplot')
pl.xlabel('X')
pl.ylabel('Y')
fig.set_size_inches(200, 30, forward=True)"""
#plt.tight_layout(pad=-10, w_pad=30, h_pad=20, rect=(0,0,1,1))
plt.subplots_adjust(top=15, right=4, left=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-50-9180d3f10234> in <module>()
#       8 #ax = fig.add_subplot(3,1,1)
#       9 df1.loc[:53][1800].plot(kind='bar')
# ---> 10 pl.xticks(range(0,53), df1.loc[:53]['Country'])
#      11 pl.title('Subplot')
#      12 pl.xlabel('X')
#
# /Users/Rafa/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1912             return self._getitem_multilevel(key)
#    1913         else:
# -> 1914             return self._getitem_column(key)
#    1915
#    1916     def _getitem_column(self, key):
#
# /Users/Rafa/anaconda2/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_column(self, key)
#    1919         # get column
#    1920         if self.columns.is_unique:
# -> 1921             return self._get_item_cache(key)
#    1922
# ...

# %%
df.iloc[:]['gdp pc test']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-51-725e9301aaf4> in <module>()
# ----> 1 df.iloc[:]['gdp pc test']
#
# NameError: name 'df' is not defined

# %%
df2 = pd.read_csv('countries.csv')

# %%
new = pd.merge(df1, df2, on='Country', how='left')

# %%
new
# Out:
#                           Country         1800         1801         1802  \
# 0                        Abkhazia          NaN          NaN          NaN
# 1                     Afghanistan   472.053500   472.053500   472.053500
# 2           Akrotiri and Dhekelia          NaN          NaN          NaN
# 3                         Albania   601.215222   601.839631   602.464688
# 4                         Algeria   766.253664   766.234779   766.215895
# 5                  American Samoa   674.453726   674.453726   674.453726
# 6                         Andorra  1260.123256  1262.214402  1264.309018
# 7                          Angola   359.932582   359.932582   359.932582
# 8                        Anguilla   775.668711   775.668711   775.668711
# 9             Antigua and Barbuda   538.376199   538.376199   538.376199
# 10                      Argentina   871.625269   871.625269   871.625269
# 11                        Armenia   378.403254   378.403254   378.403254
# ...

# %%
a = new.Country
b = new[1800]

# %%
c = new.dropna()
c = c[['Region', 1800]]
m = pd.unique(c.Region)
for i in range(len(m)):
    print 1
#c = c.loc[c['Region'] == 'EUROPE']
#c[1800]
# Out:
# 1
# 1
# 1
# 1
# 1
# 1

# %%
#c = new.dropna()
#c = new.groupby(by='Region')
#c = pd.DataFrame(c.aggregate(np.mean))
#dic = {'Africa': c[1800].AFRICA, 'Asia': c[1800].ASIA, 'Europe': c[1800].EUROPE, 'N. America': c[1800]['NORTH AMERICA'], 'Oceania': c[1800].OCEANIA, 'S. America': c[1800]['SOUTH AMERICA']}
#r = pd.DataFrame.from_dict(dic, orient={'index', 'columns'})
#d = pd.DataFrame(list(dic.iteritems()),columns=[1,2])
#r

#d

# %%
plt.figure()
#ax = plt.fig_add.subplot(1,1,1)
c[1800].plot(kind='box')
plt.ylabel('Number Of Countries Having The Income', fontsize=10)
plt.xlabel('Range Of Income Per Person', fontsize=10)
plt.title('Income Per Person '+'In Europe', fontsize=16)

#plt.set_size_inches(100, 30, forward=True)
