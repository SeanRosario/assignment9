# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt

# %%
countries = pd.read_csv('../countries.csv')

# %%
countries
# Out:
#                               Country         Region
# 0                             Algeria         AFRICA
# 1                              Angola         AFRICA
# 2                               Benin         AFRICA
# 3                            Botswana         AFRICA
# 4                             Burkina         AFRICA
# 5                             Burundi         AFRICA
# 6                            Cameroon         AFRICA
# 7                          Cape Verde         AFRICA
# 8            Central African Republic         AFRICA
# 9                                Chad         AFRICA
# 10                            Comoros         AFRICA
# 11                              Congo         AFRICA
# 12      Congo, Democratic Republic of         AFRICA
# 13                           Djibouti         AFRICA
# 14                              Egypt         AFRICA
# 15                  Equatorial Guinea         AFRICA
# 16                            Eritrea         AFRICA
# ...

# %%
income
# Out:
#                                      1800         1801         1802  \
# gdp pc test
# Abkhazia                              NaN          NaN          NaN
# Afghanistan                    472.053500   472.053500   472.053500
# Akrotiri and Dhekelia                 NaN          NaN          NaN
# Albania                        601.215222   601.839631   602.464688
# Algeria                        766.253664   766.234779   766.215895
# American Samoa                 674.453726   674.453726   674.453726
# Andorra                       1260.123256  1262.214402  1264.309018
# Angola                         359.932582   359.932582   359.932582
# Anguilla                       775.668711   775.668711   775.668711
# Antigua and Barbuda            538.376199   538.376199   538.376199
# Argentina                      871.625269   871.625269   871.625269
# Armenia                        378.403254   378.403254   378.403254
# Aruba                          575.855054   575.855054   575.855054
# ...

# %%
income_trans = income.transpose()

# %%
income_trans
# Out:
#                   0            1                      2         3         4    \
# gdp pc test  Abkhazia  Afghanistan  Akrotiri and Dhekelia   Albania   Algeria
# 1800              NaN     472.0535                    NaN  601.2152  766.2537
# 1801              NaN     472.0535                    NaN  601.8396  766.2348
# 1802              NaN     472.0535                    NaN  602.4647  766.2159
# 1803              NaN     472.0535                    NaN  603.0904   766.197
# 1804              NaN     472.0535                    NaN  603.7168  766.1781
# 1805              NaN     472.0535                    NaN  604.3438  766.1592
# 1806              NaN     472.0535                    NaN  604.9714  766.1404
# 1807              NaN     472.0535                    NaN  605.5997  766.1215
# 1808              NaN     472.0535                    NaN  606.2287  766.1026
# 1809              NaN     472.0535                    NaN  606.8583  766.0837
# ...

# %%
type(income_trans.index[2])
# Out:
# int

# %%
income[2012]
# Out:
# 0              NaN
# 1      1349.696941
# 2              NaN
# 3      6969.306283
# 4      6419.127829
# 5              NaN
# 6              NaN
# 7      5838.155376
# 8              NaN
# 9     13722.986163
# 10    15714.103181
# 11     5059.087964
# 12             NaN
# 13    36064.737277
# 14    36731.628774
# ...
# 245             NaN
# 246     3940.923984
# 247    11685.177194
# 248     4328.391158
# 249             NaN
# 250             NaN
# 251     3073.649612
# 252             NaN
# 253             NaN
# 254             NaN
# 255     2043.787776
# 256             NaN
# 257     1550.923859
# 258      545.344601
# 259             NaN
# Name: 2012, Length: 260, dtype: float64

# %%
income
# Out:
#                       gdp pc test         1800         1801         1802  \
# 0                        Abkhazia          NaN          NaN          NaN
# 1                     Afghanistan   472.053500   472.053500   472.053500
# 2           Akrotiri and Dhekelia          NaN          NaN          NaN
# 3                         Albania   601.215222   601.839631   602.464688
# 4                         Algeria   766.253664   766.234779   766.215895
# 5                  American Samoa   674.453726   674.453726   674.453726
# 6                         Andorra  1260.123256  1262.214402  1264.309018
# 7                          Angola   359.932582   359.932582   359.932582
# 8                        Anguilla   775.668711   775.668711   775.668711
# 9             Antigua and Barbuda   538.376199   538.376199   538.376199
# 10                      Argentina   871.625269   871.625269   871.625269
# 11                        Armenia   378.403254   378.403254   378.403254
# ...

# %%
income = pd.read_e

# %%
income = pd.read_excel('../indicator gapminder gdp_per_capita_ppp.xlsx', index_col=0)

# %%
# %matplotlib inline
year=2012
data = income[year]
plt.figure()
plt.hist(data.dropna(), bins=20, color='gray')
plt.title('Distribution of income per person in {}'.format(year))
plt.xlabel('income per person $')
plt.text(0.6*data.max(), 0.7*n.max(), 'Max({0}): {1:.2f}\nMin({2}): {3:.2f}'.format(data.argmax(), data.max(), data.argmin(), data.min()))
plt.show()

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-e9b54d2e22f6> in <module>()
#       3 result = data[yr]
#       4 plt.figure()
# ----> 5 plt.hist(result.dropna())
#       6 plt.title('Distribution of income per perspm in {}'.format(yr))
#       7 plt.show()
#
# /Users/sidaye/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2894                       histtype=histtype, align=align, orientation=orientation,
#    2895                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2896                       stacked=stacked, **kwargs)
#    2897         draw_if_interactive()
#    2898     finally:
#
# ...

# %%
plot_income_by_yr(2012)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-35-ac38b8824e45> in <module>()
# ----> 1 plot_income_by_yr(2012)
#
# <ipython-input-34-48c43c2a8ab9> in plot_income_by_yr(yr)
#       3     result = data[yr]
#       4     plt.figure()
# ----> 5     plt.hist(result.dropna())
#       6     plt.title('Distribution of income per perspm in {}'.format(yr))
#       7     plt.show()
#
# /Users/sidaye/anaconda/lib/python2.7/site-packages/matplotlib/pyplot.pyc in hist(x, bins, range, normed, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, hold, **kwargs)
#    2894                       histtype=histtype, align=align, orientation=orientation,
#    2895                       rwidth=rwidth, log=log, color=color, label=label,
# -> 2896                       stacked=stacked, **kwargs)
#    2897         draw_if_interactive()
# ...
